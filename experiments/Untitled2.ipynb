# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
# %load_ext autoreload
# %autoreload 2
import scipy 

from wifi import *
from wifi.util import *
from wifi import packet_detector

import warnings
warnings.filterwarnings('ignore') # yolo!

# %%
iq = np.load('/home/gaspar/git/wifi/data/limemini_lime_air.npy')

# %%
plt.plot(iq)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
packet_detector.do(iq)

# %%
plt.figure()
plt.plot(packet_detector.trace['autocorrelation'], label='autocorrelation')
plt.plot(packet_detector.trace['power'], label='power')
plt.plot(packet_detector.trace['detectionratio'], label='detectionratio')
plt.plot(packet_detector.trace['threshold'], label='threshold', color='red')
plt.legend()
plt.grid()
plt.show()
