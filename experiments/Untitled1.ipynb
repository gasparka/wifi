# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from ieee80211phy.util import *
from ieee80211phy.receiver import *
from ieee80211phy.conv_coding import *
# %load_ext autoreload
# %autoreload 2

# %%
a = '12312312321'

# %%
a[::4]
# Out:
# '1'

# %%
print('{')
for i in range(8):
    print(f"'{int_to_binstr(i, 3)}': [{np.random.randint(0, 8)}, {np.random.randint(0, 8)}, {np.random.randint(0, 8)}],")
print('}')
# Out:
# {
# '000': [1, 0, 2],
# '001': [0, 5, 3],
# '010': [4, 2, 1],
# '011': [5, 3, 3],
# '100': [7, 5, 5],
# '101': [5, 4, 3],
# '110': [1, 7, 0],
# '111': [7, 4, 2],
# }

# %%
inp = '1' * (4095*8*2)

# %%
4095*8*2*64*8*2/8/1024
# Out:
# 8190.0

# %%
conv_decode(inp, coding_rate='3/4')
# Out:
# INFO:ieee80211phy.conv_coding:Decoded 49137 bits, error_score=0, rate=3/4
# '...'

# %%
# %%timeit -n 1
# conv_decode(inp, coding_rate='3/4')
conv_decode(inp, coding_rate='3/4')
# Out:
# INFO:ieee80211phy.conv_coding:Decoded 49140 bits, error_score=2, rate=3/4
# INFO:ieee80211phy.conv_coding:Decoded 49140 bits, error_score=2, rate=3/4
# INFO:ieee80211phy.conv_coding:Decoded 49140 bits, error_score=2, rate=3/4
# INFO:ieee80211phy.conv_coding:Decoded 49140 bits, error_score=2, rate=3/4
# INFO:ieee80211phy.conv_coding:Decoded 49140 bits, error_score=2, rate=3/4
# INFO:ieee80211phy.conv_coding:Decoded 49140 bits, error_score=2, rate=3/4
# INFO:ieee80211phy.conv_coding:Decoded 49140 bits, error_score=2, rate=3/4
# 113 ms ± 654 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
timeit??

# %%
for i in range(8):
    conv_decode(inp)
# Out:
# INFO:ieee80211phy.conv_coding:Decoded 1 bits, error_score=0, rate=1/2
# INFO:ieee80211phy.conv_coding:Decoded 1 bits, error_score=0, rate=1/2
# INFO:ieee80211phy.conv_coding:Decoded 1 bits, error_score=0, rate=1/2
# INFO:ieee80211phy.conv_coding:Decoded 1 bits, error_score=0, rate=1/2
# INFO:ieee80211phy.conv_coding:Decoded 1 bits, error_score=0, rate=1/2
# INFO:ieee80211phy.conv_coding:Decoded 1 bits, error_score=0, rate=1/2
# INFO:ieee80211phy.conv_coding:Decoded 1 bits, error_score=0, rate=1/2
# INFO:ieee80211phy.conv_coding:Decoded 1 bits, error_score=0, rate=1/2

# %%
422/1000
# Out:
# 0.422

# %%
5660/10000
# Out:
# 0.566
